# %%
from anthropic import Anthropic
import json
import re
from pprint import pprint
import os
from dotenv import load_dotenv
from pydantic import BaseModel, Field
from typing import List
from collections import defaultdict

# %%
load_dotenv()
client = Anthropic(
    api_key=os.environ["ANTHROPIC_API_KEY"],
)

class StoryArc(BaseModel):
    label: str
    description: str
    characters: List[str]
    themes: List[str]

class TranscriptAnalysis(BaseModel):
    story_arcs: List[StoryArc] = Field(..., alias='story_arcs')

def extract_json(response):
    json_start = response.index("[")
    json_end = response.rfind("]")
    return json.loads(response[json_start:json_end + 1])

# %%
all_story_arcs = []

transcripts_dir = 'transcripts'
files = os.listdir(transcripts_dir)
files.sort()
max_retries = 3
for file_name in files:
    with open(os.path.join(transcripts_dir, file_name), 'r') as file:
        EPISODE_TRANSCRIPT = file.read()
    
    retries = 0
    while retries < max_retries:
        try:

            message = client.messages.create(
            model="claude-3-haiku-20240307",
            max_tokens=1024,
            temperature=0,
            system="You are good at extracting story arcs from transcript of TV episodes. You will be a given a transcript of an episode. Your task is to extract the main story arcs from this episode. A story arc is a narrative thread that runs through part or all of the episode, involving certain characters and exploring certain themes. An arc has a beginning, middle and end. It will often center around a conflict or challenge that the characters need to overcome. \n\nFor example, in an episode of Friends, one story arc might be:\n- Joey and Chandler centers around a humorous fight over a chair. The conflict begins when Chandler leaves the room for a moment and Joey takes his seat. When Chandler returns and demands the seat back, Joey refuses, leading to a series of tit-for-tat pranks between the two. The situation escalates comically when Joey decides to make a point about not sharing by wearing all of Chandler's clothes at once, declaring, \"Look at me, I'm Chandler. Could I BE wearing any more clothes?\" This is done as a form of exaggerated revenge for Chandler hiding Joey's underwear, and it leads to a memorable and funny moment involving physical comedy and slapstick humor.\n\nPlease carefully read through the transcript and identify the main story arcs. For each one, think about:\n<scratchpad>\n- What is the key conflict or challenge driving this arc? How is it set up and how is it resolved?\n- Which characters are most central to this arc? What role do they each play?\n- What deeper themes, if any, are explored through this storyline? \n</scratchpad>\n\nThen, output the story arcs in the following JSON format:\n\n<example>\n[\n  {\n    \"label\": \"Joey and Chandler's Fight\",\n    \"description\": \"Joey and Chandler bicker over a chair leading to escalating pranks including Joey wearing all of Chandler's clothes as an act of revenge.\",\n    \"characters\": [\"Joey\", \"Chandler\"],\n    \"themes\": [\"Friendship\", \"Conflict\", \"Petty revenge\"]\n  },\n  ...\n]\n</example>\n\n \n\nMake sure the story arc objects are printed in valid JSON format. Only include the valid JSON and do not include any other text. I just want the JSON from you.",
            messages=[
                    {
                        "role": "user",
                        "content": [
                            {
                                "type": "text",
                                "text": f"\n\n<episode_transcript>\n{EPISODE_TRANSCRIPT}\n</episode_transcript>\n\n"
                            }
                        ]
                    }
                ]
            ).content[0].text
            # print(message)

            json_output = extract_json(message)
            if json_output is not None:
                print("JSON Output:")
                pprint(json_output)
                all_story_arcs.extend(json_output)
                break
            else:
                retries += 1
                print(f"Retrying API call... Attempt {retries}/{max_retries}")
        except Exception as e:
            retries += 1
            print(f"An error occurred: {e}. Retrying... Attempt {retries}/{max_retries}")

if all_story_arcs:
    print("First Story Arc:")
    pprint(all_story_arcs[0])
else:
    print("No story arcs were extracted.")
# Out:
# JSON Output:
# [{'characters': ['Josh', 'Mary Marsh', 'Al Caldwell', 'Toby', 'C.J.'],
#   'description': 'Josh makes controversial remarks about Christian '
#                  'conservatives on a TV talk show, angering figures like Mary '
#                  'Marsh and Al Caldwell. This leads to a confrontation where '
#                  'Josh is pressured to apologize and make concessions, but he '
#                  'resists until the President intervenes.',
#   'label': "Josh's Controversial TV Appearance",
#   'themes': ['Political conflict', 'Freedom of speech', 'Moral values']},
#  {'characters': ['President Bartlet', 'Leo', 'Mrs. Landingham'],
#   'description': 'The President is injured in a bicycle accident, which '
#                  'becomes a source of embarrassment and media attention for '
#                  "the White House. This incident highlights the President's "
#                  'tendency to act impulsively when upset.',
#   'label': "The President's Bicycle Accident",
#   'themes': ['Leadership', 'Vulnerability', 'Impulse control']},
#  {'characters': ['Sam', 'Laurie', 'Mallory'],
#   'description': 'Sam accidentally switches pagers with a woman who turns out '
#                  'to be a high-priced escort. This leads to an awkward '
#                  'encounter where Sam has to confront the reality of her '
#                  'profession. Meanwhile, Sam also struggles to give a tour of '
#                  "the White House to Leo's daughter's class, demonstrating his "
#                  "lack of knowledge about the building's history.",
#   'label': "Sam's Mistaken Identity",
#   'themes': ['Moral ambiguity', 'Incompetence', 'Fatherhood']},
#  {'characters': ['Mandy', 'Josh', 'Lloyd Russell'],
#   'description': "It's revealed that Mandy has left her high-paying job to "
#                  'start consulting work, and that she is now dating Senator '
#                  'Lloyd Russell, who may run against the President. This '
#                  'creates tension with Josh, her former boyfriend.',
#   'label': "Mandy's New Job",
#   'themes': ['Changing allegiances', 'Personal/professional conflicts']}]
# JSON Output:
# [{'characters': ['Bartlet', 'C.J.', 'Josh', 'Toby'],
#   'description': 'The President made a joke about golfers that offends the '
#                  'Ryder Cup team, leading to them declining an invitation to '
#                  'the White House. This causes a PR headache for the '
#                  'administration, with C.J. and others having to deal with the '
#                  'fallout.',
#   'label': "Bartlet's Joke Causes Backlash",
#   'themes': ['Presidential leadership',
#              'Media relations',
#              'Unintended consequences']},
#  {'characters': ['Sam', 'Josh', 'Toby', 'Laurie/Brittany'],
#   'description': 'Sam accidentally sleeps with a woman he later discovers is a '
#                  'call girl. He struggles with how to handle the situation, '
#                  'seeking advice from Josh and Toby, and ultimately tries to '
#                  'connect with the woman in a more personal way.',
#   'label': "Sam's Encounter with a Call Girl",
#   'themes': ['Ethics', 'Morality', 'Redemption']},
#  {'characters': ['Mandy', 'Josh', 'Leo', 'Toby'],
#   'description': "Despite Josh's objections, Leo and the senior staff decide "
#                  'to bring back Mandy as a media consultant for the '
#                  'administration. This leads to tension as Mandy is '
#                  'reintegrated into the team.',
#   'label': 'Mandy Returns to the White House',
#   'themes': ['Teamwork', 'Interpersonal dynamics', 'Staffing decisions']},
#  {'characters': ['Bartlet', 'Leo'],
#   'description': 'In the final act, the President is informed that his '
#                  'physician, Morris Tolliver, has been killed in a plane crash '
#                  'that was likely caused by a Syrian missile strike. This '
#                  'tragic event shakes the President and sets up a potential '
#                  'international crisis response.',
#   'label': 'Tragedy Strikes as Morris Tolliver Dies',
#   'themes': ['Tragedy', 'Foreign policy', 'Presidential decision-making']}]
# JSON Output:
# [{'characters': ['President Bartlet', 'Leo McGarry', 'Admiral Fitzwallace'],
#   'description': 'President Bartlet grapples with the concept of a '
#                  'proportional military response, ultimately deciding that a '
#                  'disproportional response is warranted to send a strong '
#                  'message. This internal conflict is explored as Bartlet '
#                  'debates the military options with his national security '
#                  'team.',
#   'label': "The President's Struggle with Proportional Response",
#   'themes': ['Use of military force',
#              'Proportionality in warfare',
#              'Presidential decision-making']},
#  {'characters': ['Sam Seaborn', 'C.J. Cregg'],
#   'description': 'C.J. confronts Sam about his relationship with a woman who '
#                  'turns out to be a call girl. Sam defends his actions, '
#                  'arguing that he cares for the woman and is trying to help '
#                  'her, not just engage in a tawdry affair. C.J. is concerned '
#                  'about the optics and potential scandal.',
#   'label': "Sam's Relationship with a Call Girl",
#   'themes': ['Ethics and morality in government',
#              'Reputation and public perception']},
#  {'characters': ['Charlie Young', 'President Bartlet', 'Josh Lyman'],
#   'description': 'Josh interviews Charlie Young, a young black man whose '
#                  'mother was recently killed in the line of duty as a police '
#                  'officer. Despite some initial hesitation, the President '
#                  'takes a liking to Charlie and hires him as the new personal '
#                  'aide, recognizing his potential and wanting to help him.',
#   'label': 'Charlie Young Joins the White House Staff',
#   'themes': ['Opportunity and mentorship', 'Diversity in government']}]
# JSON Output:
# [{'characters': ['Josh',
#                  'Leo',
#                  'Bartlet',
#                  'Hoynes',
#                  'Katzenmoyer',
#                  'Wick',
#                  'Tillinghouse'],
#   'description': 'The White House staff is working to secure the necessary '
#                  'votes to pass a gun control bill (802) in Congress. They '
#                  'face challenges in getting the final few votes, including '
#                  'from Congressman Katzenmoyer, Congressman Wick, and '
#                  'Congressman Tillinghouse. Josh and Leo use various tactics '
#                  'to try to persuade the holdout Congressmen, including veiled '
#                  'threats and promises of political favors. In the end, the '
#                  'Vice President is able to secure the final vote from '
#                  'Tillinghouse, allowing the bill to pass.',
#   'label': 'Passing the Gun Control Bill',
#   'themes': ['Gun control',
#              'Legislative process',
#              'Compromise',
#              'Power dynamics']},
#  {'characters': ['Toby', 'Sam', 'Leela'],
#   'description': 'Toby discloses in the financial reports that he has made a '
#                  'large profit from a technology stock investment, raising '
#                  'concerns about potential insider trading or market '
#                  'manipulation. Toby claims ignorance, but the White House '
#                  "Counsel's office wants to investigate further. Sam proposes "
#                  'a solution where Toby agrees to reduce his salary and cash '
#                  'out the stock to avoid even the appearance of impropriety.',
#   'label': "Toby's Stock Market Windfall",
#   'themes': ['Ethics', 'Perception vs. reality', 'Accountability']},
#  {'characters': ['Leo', 'Jenny'],
#   'description': "Leo's wife Jenny leaves him after he misses their "
#                  'anniversary dinner to continue working on the gun control '
#                  'bill. This puts a strain on their marriage, with Jenny '
#                  'feeling that Leo prioritizes his work over their '
#                  'relationship. The episode ends with Leo attending a secret '
#                  'support group meeting, suggesting he is struggling with '
#                  'personal issues.',
#   'label': "Leo's Marital Troubles",
#   'themes': ['Work-life balance', 'Marriage', 'Addiction']}]
# JSON Output:
# [{'characters': ['Bartlet', 'Toby', 'Josh', 'Charlie'],
#   'description': 'Bartlet plays a basketball game with his staff, including '
#                  "Toby. Toby challenges Bartlet's competitiveness and accuses "
#                  'him of cheating in the past. Bartlet brings in a '
#                  'professional basketball player, Rodney Grant, to join his '
#                  "team, leading to a confrontation with Toby over Bartlet's "
#                  'tactics.',
#   'label': "Bartlet's Basketball Game and Rivalry with Toby",
#   'themes': ['Friendship', 'Rivalry', 'Competitiveness']},
#  {'characters': ['Josh', 'C.J.', 'Sam'],
#   'description': 'Josh is given a special card by the NSC with instructions on '
#                  'what to do in the event of a nuclear attack. He is troubled '
#                  'that he was given the card but his colleagues were not, '
#                  'feeling it separates him from his friends. He ultimately '
#                  'decides he wants to be with his friends and family in a '
#                  "crisis, rather than following the card's instructions.",
#   'label': "Josh's Distress Over the NSC Card",
#   'themes': ['Loyalty', 'Friendship', 'Mortality']},
#  {'characters': ['Bartlet',
#                  'Leo',
#                  'C.J.',
#                  'Mandy',
#                  'Mrs. Landingham',
#                  'Zoey',
#                  'Charlie',
#                  'Josh'],
#   'description': 'Bartlet hosts a chili night in the White House residence, '
#                  'bringing his senior staff together in a more casual, social '
#                  'setting. He reflects on the strengths and qualities of his '
#                  'staff members, expressing his appreciation for them as '
#                  'people beyond just their roles.',
#   'label': "Bartlet's Chili Night and Appreciation for His Staff",
#   'themes': ['Teamwork', 'Appreciation', 'Camaraderie']}]
# JSON Output:
# [{'characters': ['Bartlet', 'Zoey', 'Secret Service'],
#   'description': "A mentally unstable woman attempts to target the President's "
#                  'daughter Zoey, leading to increased security measures. '
#                  "Bartlet is deeply concerned for Zoey's safety and has an "
#                  'emotional conversation with her about the need for '
#                  'protection.',
#   'label': "The President's Daughter Zoey is Threatened",
#   'themes': ['Fatherhood', 'Security', 'Vulnerability']},
#  {'characters': ['Bartlet', 'Leo', 'Josh', 'Toby', 'Sam', 'C.J.'],
#   'description': 'The President and his senior staff gather for a late-night '
#                  'poker game, engaging in banter and trivia challenges. This '
#                  'provides a glimpse into their camaraderie and the lighter '
#                  'side of working in the White House.',
#   'label': 'The White House Staff Plays Poker',
#   'themes': ['Friendship', 'Teamwork', 'Work-life balance']},
#  {'characters': ['Toby', 'Mandy', 'Gladman', 'Skinner', 'Willis'],
#   'description': 'The White House team negotiates with a group of Congressmen '
#                  'to drop an amendment prohibiting the use of statistical '
#                  'sampling in the census. Toby makes a persuasive argument '
#                  'based on the Constitution, leading one Congressman to change '
#                  'his vote.',
#   'label': 'The Census Amendment Debate',
#   'themes': ['Policymaking',
#              'Constitutional interpretation',
#              'Bipartisanship']},
#  {'characters': ['Josh', 'Sam', 'Charlie', 'Zoey', 'Mallory', 'C.J.'],
#   'description': 'Josh, Sam, Charlie, Zoey, Mallory and C.J. go to a bar, '
#                  'where Zoey is accosted by some aggressive men. Charlie and '
#                  'the others intervene, leading to the involvement of the '
#                  'Secret Service. This highlights the challenges of the '
#                  "President's family having a normal social life.",
#   'label': 'The White House Staff Goes Out for Drinks',
#   'themes': ['Friendship', 'Privilege', 'Responsibility']},
#  {'characters': ['Leo', 'Bartlet'],
#   'description': 'Leo confides in the President that his wife Jenny is asking '
#                  "for a divorce, much to Bartlet's dismay. Bartlet urges Leo "
#                  'to fix the situation, but Leo expresses resignation about '
#                  'the state of his marriage.',
#   'label': "Leo's Marital Troubles",
#   'themes': ['Marriage', 'Friendship', 'Work-life balance']}]
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 1/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 2/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 3/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 1/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 2/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 3/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 1/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 2/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 3/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 1/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 2/3
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your per-minute rate limit (https://docs.anthropic.com/claude/reference/rate-limits); see the response headers for current usage. Please reduce the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}. Retrying... Attempt 3/3
# First Story Arc:
# {'characters': ['Josh', 'Mary Marsh', 'Al Caldwell', 'Toby', 'C.J.'],
#  'description': 'Josh makes controversial remarks about Christian '
#                 'conservatives on a TV talk show, angering figures like Mary '
#                 'Marsh and Al Caldwell. This leads to a confrontation where '
#                 'Josh is pressured to apologize and make concessions, but he '
#                 'resists until the President intervenes.',
#  'label': "Josh's Controversial TV Appearance",
#  'themes': ['Political conflict', 'Freedom of speech', 'Moral values']}

# %%
transcript_analysis = TranscriptAnalysis(story_arcs=all_story_arcs)
for arc in transcript_analysis.story_arcs:
    print(arc.label)
# Out:
# Josh's Controversial TV Appearance
# The President's Bicycle Accident
# Sam's Mistaken Identity
# Mandy's New Job
# Bartlet's Joke Causes Backlash
# Sam's Encounter with a Call Girl
# Mandy Returns to the White House
# Tragedy Strikes as Morris Tolliver Dies
# The President's Struggle with Proportional Response
# Sam's Relationship with a Call Girl
# Charlie Young Joins the White House Staff
# Passing the Gun Control Bill
# Toby's Stock Market Windfall
# Leo's Marital Troubles
# Bartlet's Basketball Game and Rivalry with Toby
# Josh's Distress Over the NSC Card
# Bartlet's Chili Night and Appreciation for His Staff
# The President's Daughter Zoey is Threatened
# The White House Staff Plays Poker
# The Census Amendment Debate
# The White House Staff Goes Out for Drinks
# Leo's Marital Troubles

# %%
for arc in transcript_analysis.story_arcs:
    print(arc.themes)
# Out:
# ['Political conflict', 'Freedom of speech', 'Moral values']
# ['Leadership', 'Vulnerability', 'Impulse control']
# ['Moral ambiguity', 'Incompetence', 'Fatherhood']
# ['Changing allegiances', 'Personal/professional conflicts']
# ['Presidential leadership', 'Media relations', 'Unintended consequences']
# ['Ethics', 'Morality', 'Redemption']
# ['Teamwork', 'Interpersonal dynamics', 'Staffing decisions']
# ['Tragedy', 'Foreign policy', 'Presidential decision-making']
# ['Use of military force', 'Proportionality in warfare', 'Presidential decision-making']
# ['Ethics and morality in government', 'Reputation and public perception']
# ['Opportunity and mentorship', 'Diversity in government']
# ['Gun control', 'Legislative process', 'Compromise', 'Power dynamics']
# ['Ethics', 'Perception vs. reality', 'Accountability']
# ['Work-life balance', 'Marriage', 'Addiction']
# ['Friendship', 'Rivalry', 'Competitiveness']
# ['Loyalty', 'Friendship', 'Mortality']
# ['Teamwork', 'Appreciation', 'Camaraderie']
# ['Fatherhood', 'Security', 'Vulnerability']
# ['Friendship', 'Teamwork', 'Work-life balance']
# ['Policymaking', 'Constitutional interpretation', 'Bipartisanship']
# ['Friendship', 'Privilege', 'Responsibility']
# ['Marriage', 'Friendship', 'Work-life balance']

# %%
class ThemeCluster(BaseModel):
    theme_cluster_name: str
    themes: List[str]

class ThemeClustersAnalysis(BaseModel):
    theme_clusters: List[ThemeCluster]

# %%
THEMES = []

for arc in transcript_analysis.story_arcs:
    THEMES.extend(arc.themes)

# Remove duplicates
THEMES = list(set(THEMES))

print(THEMES)
# Out:
# ['Impulse control', 'Perception vs. reality', 'Incompetence', 'Compromise', 'Use of military force', 'Reputation and public perception', 'Power dynamics', 'Fatherhood', 'Competitiveness', 'Camaraderie', 'Gun control', 'Presidential leadership', 'Ethics', 'Moral values', 'Marriage', 'Rivalry', 'Freedom of speech', 'Privilege', 'Leadership', 'Personal/professional conflicts', 'Ethics and morality in government', 'Accountability', 'Moral ambiguity', 'Interpersonal dynamics', 'Legislative process', 'Diversity in government', 'Friendship', 'Opportunity and mentorship', 'Media relations', 'Security', 'Policymaking', 'Presidential decision-making', 'Bipartisanship', 'Addiction', 'Responsibility', 'Redemption', 'Teamwork', 'Morality', 'Tragedy', 'Loyalty', 'Foreign policy', 'Proportionality in warfare', 'Political conflict', 'Appreciation', 'Changing allegiances', 'Vulnerability', 'Mortality', 'Work-life balance', 'Constitutional interpretation', 'Staffing decisions', 'Unintended consequences']

# %%
clustering_response = client.messages.create(
    model="claude-3-haiku-20240307",
    max_tokens=1000,
    temperature=0,
    system="Your task is to group these themes into clusters based on their semantic similarity. Themes that are closely related in meaning should be grouped together.\n\n<scratchpad>\nTo cluster the themes:\n1. Read through the full list of themes to get an overall sense of the topics covered\n2. Identify major thematic categories that multiple themes fall under\n3. Go through the list and assign each theme to the most relevant category \n4. For any themes that don't fit well into the main categories, consider if they warrant their own category or are outliers\n5. Review the categories and their assigned themes to assess if the groupings make sense\n6. Come up with concise, descriptive names for each finalized category\n</scratchpad>\n\nPlease return your output as a JSON array, with each object in the array containing:\n- theme_cluster_name (string): A descriptive name for the cluster of themes \n- themes (list of strings): The themes that have been grouped into that cluster\n\nEnclose your final JSON output inside <result> tags.",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": f"Here is a list of themes extracted from story arcs of TV series episodes:\n\n<themes>\n{THEMES}\n</themes>"
                }
            ]
        }
    ]
).content[0].text
clustering_json = extract_json(clustering_response)

# %%
pprint(clustering_json)
theme_clusters_analysis = ThemeClustersAnalysis(theme_clusters=clustering_json)

for cluster in theme_clusters_analysis.theme_clusters:
    print(cluster.theme_cluster_name)
# Out:
# [{'theme_cluster_name': 'Government and Politics',
#   'themes': ['Use of military force',
#              'Reputation and public perception',
#              'Power dynamics',
#              'Presidential leadership',
#              'Ethics and morality in government',
#              'Accountability',
#              'Legislative process',
#              'Diversity in government',
#              'Media relations',
#              'Policymaking',
#              'Presidential decision-making',
#              'Bipartisanship',
#              'Foreign policy',
#              'Proportionality in warfare',
#              'Political conflict',
#              'Constitutional interpretation',
#              'Staffing decisions']},
#  {'theme_cluster_name': 'Interpersonal Dynamics',
#   'themes': ['Compromise',
#              'Camaraderie',
#              'Competitiveness',
#              'Rivalry',
#              'Interpersonal dynamics',
#              'Friendship',
#              'Opportunity and mentorship',
#              'Teamwork',
#              'Loyalty',
#              'Changing allegiances',
#              'Vulnerability']},
#  {'theme_cluster_name': 'Ethics and Morality',
#   'themes': ['Perception vs. reality',
#              'Moral values',
#              'Ethics',
#              'Moral ambiguity',
#              'Morality',
#              'Responsibility',
#              'Redemption']},
#  {'theme_cluster_name': 'Personal and Professional Challenges',
#   'themes': ['Impulse control',
#              'Incompetence',
#              'Fatherhood',
#              'Personal/professional conflicts',
#              'Addiction',
#              'Tragedy',
#              'Work-life balance',
#              'Unintended consequences']},
#  {'theme_cluster_name': 'Social Issues',
#   'themes': ['Gun control',
#              'Freedom of speech',
#              'Privilege',
#              'Leadership',
#              'Appreciation']},
#  {'theme_cluster_name': 'Outliers', 'themes': ['Mortality']}]
# Government and Politics
# Interpersonal Dynamics
# Ethics and Morality
# Personal and Professional Challenges
# Social Issues
# Outliers

# %%
# Step 1: Map each theme to its corresponding cluster
theme_to_cluster = {}
for cluster in theme_clusters_analysis.theme_clusters:
    for theme in cluster.themes:
        theme_to_cluster[theme] = cluster.theme_cluster_name

# Step 2: Create a mapping of characters to the themes present in the arcs they are involved in
character_to_themes = defaultdict(list)
for arc in transcript_analysis.story_arcs:
    for character in arc.characters:
        character_to_themes[character].extend(arc.themes)

# Step 3: Determine the most common theme cluster for each character
character_to_theme_cluster = {}
for character, themes in character_to_themes.items():
    # Count the occurrences of each cluster for the current character
    cluster_count = defaultdict(int)
    for theme in themes:
        if theme in theme_to_cluster:
            cluster_count[theme_to_cluster[theme]] += 1

    # Find the most common cluster for the current character
    if cluster_count:
        character_to_theme_cluster[character] = max(cluster_count, key=cluster_count.get)

for character, cluster_name in character_to_theme_cluster.items():
    print(f"{character}: {cluster_name}")
# Out:
# Josh: Interpersonal Dynamics
# Mary Marsh: Government and Politics
# Al Caldwell: Government and Politics
# Toby: Government and Politics
# C.J.: Interpersonal Dynamics
# President Bartlet: Government and Politics
# Leo: Interpersonal Dynamics
# Mrs. Landingham: Interpersonal Dynamics
# Sam: Ethics and Morality
# Laurie: Personal and Professional Challenges
# Mallory: Ethics and Morality
# Mandy: Interpersonal Dynamics
# Lloyd Russell: Interpersonal Dynamics
# Bartlet: Interpersonal Dynamics
# Laurie/Brittany: Ethics and Morality
# Leo McGarry: Government and Politics
# Admiral Fitzwallace: Government and Politics
# Sam Seaborn: Government and Politics
# C.J. Cregg: Government and Politics
# Charlie Young: Interpersonal Dynamics
# Josh Lyman: Interpersonal Dynamics
# Hoynes: Government and Politics
# Katzenmoyer: Government and Politics
# Wick: Government and Politics
# Tillinghouse: Government and Politics
# Leela: Ethics and Morality
# Jenny: Personal and Professional Challenges
# Charlie: Interpersonal Dynamics
# Zoey: Interpersonal Dynamics
# Secret Service: Personal and Professional Challenges
# Gladman: Government and Politics
# Skinner: Government and Politics
# Willis: Government and Politics
